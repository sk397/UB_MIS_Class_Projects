# %%
import pandas as pd
import numpy as np

# %%
airbnb = pd.read_csv('airbnb.csv')

# %%
airbnb.columns #Getting the heads of the csv
# Out:
# Index(['id', 'host_days', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_listings_count',
#        'host_identity_verified', 'neighbourhood_cleansed', 'city',
#        'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms',
#        'beds', 'bed_type', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable', 'cancellation_policy',
#        'reviews_per_month'],
#       dtype='object')

# %%
#create a hisogram for price, with axis labels
ax=airbnb.price.hist()
ax.set_xlabel('Price Per Day')
ax.set_ylabel('count of prices')
# Out:
# Text(0, 0.5, 'count of prices')

# %%
#Find the stats of the Price
airbnb['price'].describe()
# Out:
# count    3583.000000
# mean      173.925202
# std       148.362139
# min        10.000000
# 25%        85.000000
# 50%       150.000000
# 75%       220.000000
# max      4000.000000
# Name: price, dtype: float64

# %%
airbnb = airbnb.dropna(subset=['price'])

airbnb = airbnb[airbnb ['price'] > 0]

ax = airbnb['price'].hist()
ax.set_xlabel('Price Per Day')
ax.set_ylabel('count of Prices')
# Out:
# Text(0, 0.5, 'count of Prices')

# %%
airbnb['price'].describe()
# Out:
# count    3583.000000
# mean      173.925202
# std       148.362139
# min        10.000000
# 25%        85.000000
# 50%       150.000000
# 75%       220.000000
# max      4000.000000
# Name: price, dtype: float64
